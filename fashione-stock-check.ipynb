# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Marta Ponti Product Stock Listing - Product Stock Listing.csv.csv")
df.head()
# Out:
#      Style Colour  Size Description   Category      PLU  Unit Cost  \
# 0  3120440  BRUNO   NaN    side bag    MAN BAG  2938900         41
# 1  3120685  BLACK   NaN   briefcase  BRIEFCASE  2939000        109
# 2  3120815  BLACK   NaN   briefcase  BRIEFCASE  2939200         89
# 3  3120815  BRUNO   NaN   briefcase  BRIEFCASE  2939300         89
# 4  8105817  BLACK   NaN     handbag   HANDBAGS  2939400         75
#
#    Unit Retail  Units  Total Cost Total Retail
# 0        106.6      1          41        106.6
# 1        283.4      0           0            0
# 2        231.4      0           0            0
# 3        231.4      1          89        231.4
# 4        195.0      0           0            0

# %%
df[df['Units'] <= 0][['Style', 'Colour', 'Size', 'Category', 'PLU', 'Unit Cost', 'Units']].to_csv('Negative or Zero Marta Ponti Stock.csv', index=False)
