# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Google Analytics - Sheet1.csv", thousands=',')
df['Sessions'] = df['Sessions'].astype(int)
df.head()
# Out:
#                     Landing page  Sessions  Users  New users  Engagement rate  \
# 0                              /      9950   7709       6452         0.466231
# 1   /mens-c4/leather-jackets-c25      1932   1750       1446         0.705487
# 2  /ladies-c3/leather-jackets-c9      1854   1637       1364         0.684466
# 3                      (not set)      1852   1267          5         0.039417
# 4             /weekly-deals-c164      1777   1429       1237         0.344963
#
#    Average engagement time per session  Conversions  Total revenue
# 0                            61.209347           75        9052.20
# 1                            90.478778            8        1487.23
# 2                            89.141855           16        1944.13
# 3                             7.650648            8        1490.11
# 4                            10.962296            0           0.00

# %%
print(df)
# Out:
#                                            Landing page  Sessions  Users  \
# 0                                                     /      9950   7709
# 1                          /mens-c4/leather-jackets-c25      1932   1750
# 2                         /ladies-c3/leather-jackets-c9      1854   1637
# 3                                             (not set)      1852   1267
# 4                                    /weekly-deals-c164      1777   1429
# ...                                                 ...       ...    ...
# 4995  /handbags-c6/ashwood-c30/large-padded-leather-...         1      1
# 4996  /handbags-c6/ashwood-c30/large-studded-clutch-...         1      1
# 4997  /handbags-c6/ashwood-c30/large-studded-clutch-...         1      1
# 4998  /handbags-c6/ashwood-c30/leather-crossbody-bag...         1      1
# 4999  /handbags-c6/ashwood-c30/luxury-croc-print-lea...         1      1
#
#       New users  Engagement rate  Average engagement time per session  \
# ...
