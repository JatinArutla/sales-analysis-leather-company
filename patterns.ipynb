# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

df = pd.read_csv('unduplicated_orders.csv')
df['date'] = pd.to_datetime(df['date'])

# %%
df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
# df[df['customs_description'] == 'January Sale 2021']['title'].value_counts()

# %%
l = [[2, 2021], [3, 2021], [1, 2022], [2, 2022], [3, 2022], [1, 2023], [2, 2023], [3, 2023], [4, 2021], [5, 2021], [6, 2021], [4, 2022], [5, 2022], [6, 2022], [4, 2023], [5, 2023], [6, 2023], [7, 2021], [8, 2021], [9, 2021], [7, 2022], [8, 2022], [9, 2022], [7, 2023], [8, 2023], [9, 2023], [10, 2021], [11, 2021], [12, 2021], [10, 2022], [11, 2022], [12, 2022], [10, 2023], [11, 2023], [12, 2023]]
temp_df = df[(df['date'].dt.month == 1) & (df['date'].dt.year == 2021)].groupby('customs_description')['quantity'].sum().reset_index().sort_values(by='quantity', ascending=False).rename(columns={'quantity': f'1-2021'})
for i in l:
    temp_df = pd.merge(temp_df, df[(df['date'].dt.month == i[0]) & (df['date'].dt.year == i[1])].groupby('customs_description')['quantity'].sum().reset_index().rename(columns={'quantity': f'{i[0]}-{i[1]}'}), on='customs_description', how='outer')

temp_df.replace({np.NaN: 0}, inplace=True)

# %%
temp_df['Mean-Jan'] = temp_df[['1-2021', '1-2022', '1-2023']].mean(axis=1).round()
temp_df['Mean-Feb'] = temp_df[['2-2021', '2-2022', '2-2023']].mean(axis=1).round()
temp_df['Mean-Mar'] = temp_df[['3-2021', '3-2022', '3-2023']].mean(axis=1).round()

temp_df['Mean-Apr'] = temp_df[['4-2021', '4-2022', '4-2023']].mean(axis=1).round()
temp_df['Mean-May'] = temp_df[['5-2021', '5-2022', '5-2023']].mean(axis=1).round()
temp_df['Mean-Jun'] = temp_df[['6-2021', '6-2022', '6-2023']].mean(axis=1).round()

temp_df['Mean-Jul'] = temp_df[['7-2021', '7-2022', '7-2023']].mean(axis=1).round()
temp_df['Mean-Aug'] = temp_df[['8-2021', '8-2022', '8-2023']].mean(axis=1).round()
temp_df['Mean-Sep'] = temp_df[['9-2021', '9-2022', '9-2023']].mean(axis=1).round()

temp_df['Mean-Oct'] = temp_df[['10-2021', '10-2022', '10-2023']].mean(axis=1).round()
temp_df['Mean-Nov'] = temp_df[['11-2021', '11-2022', '11-2023']].mean(axis=1).round()
temp_df['Mean-Dec'] = temp_df[['12-2021', '12-2022', '12-2023']].mean(axis=1).round()

m = temp_df.select_dtypes(np.number)
temp_df[m.columns]= m.round().astype('Int64')

# %%
temp_df[:15].sort_values(by='Mean-Jan', ascending=False).reset_index(drop=True)
# Out:
#                           customs_description  1-2021  2-2021  3-2021  1-2022  \
# 0                           January Sale 2021     321     223     208     268
# 1                           Ladies > Handbags      50      56      66     217
# 2             Ladies > Ladies Jackets & Coats     106     100      99     157
# 3                          Mens > Accessories     112     113      75     101
# 4       Mens > Leather Jackets > Biker Styles     101      78      97      97
# 5                           Ladies > Footwear      80      16      13      35
# 6                           Luggage > Holdall      30      20      21      52
# 7               Ladies > Accessories > Gloves      82      63      12      28
# 8                             Ladies > Purses      16      11      33      32
# 9     Mens > Man Bags & Briefcases > WashBags      10       6       7      16
# 10                     Mens > Mens Waistcoats      24      12      10       8
# 11                Mens > Mens Jackets & Coats      26      11       5      10
# 12  Mens > Man Bags & Briefcases > Briefcases       8      11       6       8
# 13           Sheepskin & Fur > Sheepskin Hats      19       9       5      11
# 14         Gift & Accessories > Ladies Gloves       8       2       2       4
#
#     2-2022  3-2022  1-2023  2-2023  3-2023  4-2021  5-2021  6-2021  4-2022  \
# 0      184     180     237     101     126     213     256     191     163
# 1      169     201     208      54      86      78      84      59     184
# 2      132     126     122      65      95      79     112      53     112
# 3      108      69     166      58      74      53      60      70      66
# 4       79     113     148      87      90      81     103      68      97
# 5       16       8      76      22      26      10       7       1       6
# 6       24      47      94      41      42      31      45      48      67
# 7        8       8      51      16      11      11       7       3       6
# 8       29      51      93      48      79      19       8      16      26
# 9       14      18      33      32      15      10      15      11      18
# 10      16      19      22      10      12      17      14       6      18
# 11       3       1      16       5      14       7       1       1       5
# 12      14      10      28      17      20      10      11      13       5
# 13       5       2       7       1       0       8       0       0       2
# 14       2       1      19      10       5       0       0       0       1
#
#     5-2022  6-2022  4-2023  5-2023  6-2023  7-2021  8-2021  9-2021  7-2022  \
# 0      144      93     100      99      49     202     274     310     117
# 1      317     151     127     109      69      97     159     193     172
# 2       78      33      97      50      16      73      74     172      41
# 3       69      83      59      42      48      59      92      76      81
# 4       67      32      72      60      22      51      93      80      55
# 5        8       5      14      10       5       4      15      24       5
# 6       63      68      26      29      25      47      88     124      36
# 7        1       1       4       1       0       3       7      14       0
# 8       49      38      55      52      36      15      31      30      33
# 9       13      29      15      12      17       9      33      20      18
# 10      33       9       6      19       5      14      25      13      11
# 11       0       3       3       5       2       2       5      11       2
# 12       9       9      11      14       8       7      27      12      11
# 13       0       0       0       0       1       0       1       1       0
# 14       1       0       1       0       0       0       1       3       1
#
#     8-2022  9-2022  7-2023  8-2023  9-2023  10-2021  11-2021  12-2021  \
# 0       98     135      89     103      99      388      677      764
# 1      129     168     112     122     143      204      392      480
# 2       45     129      27      50      59      211      383      369
# 3       72      95      59      67      74      155      321      521
# 4       79     209      40      57      55      149      213      248
# 5       11      21      10      11      16       28       50      136
# 6       52      47      65      61      56       99      193      191
# 7        6      11       1       3       6       43      128      275
# 8       47      64      32      55      62       43       97      153
# 9       20      28      27      27      29       17       90      124
# 10       9      15       3      11       5       29       41       45
# 11       2      10       3       3       5       12       40       34
# 12       9      15      22      24      15       21       42       44
# 13       1      13       0       0       2        5       19       27
# 14       0       2       1       3      12        5       12       41
#
#     10-2022  11-2022  12-2022  10-2023  11-2023  12-2023  Mean-Jan  Mean-Feb  \
# 0       173      257      401      146      259      362       275       169
# 1       164      244      472      186      188      282       158        93
# 2       157      170      250      133      177      180       128        99
# 3        97      253      556      154      327      325       126        93
# 4       202      219      260       85      142      177       115        81
# 5        29      112      299       40       65       82        64        18
# 6        36       79      130       94      163      259        59        28
# 7        23       41      213       20       61      114        54        29
# 8       103      127      339       52      100      195        47        29
# 9        23       88      136       63      108      169        20        17
# 10       36       25       34       22       22       32        18        13
# 11       23       30       25       13       34       23        17         6
# 12       22       18       49       20       27       47        15        14
# 13        5        1       47        6       10       15        12         5
# 14        3       10      259       28       97      138        10         5
#
#     Mean-Mar  Mean-Apr  Mean-May  Mean-Jun  Mean-Jul  Mean-Aug  Mean-Sep  \
# 0        171       159       166       111       136       158       181
# 1        118       130       170        93       127       137       168
# 2        107        96        80        34        47        56       120
# 3         73        59        57        67        66        77        82
# 4        100        83        77        41        49        76       115
# 5         16        10         8         4         6        12        20
# 6         37        41        46        47        49        67        76
# 7         10         7         3         1         1         5        10
# 8         54        33        36        30        27        44        52
# 9         13        14        13        19        18        27        26
# 10        14        14        22         7         9        15        11
# 11         7         5         2         2         2         3         9
# 12        12         9        11        10        13        20        14
# 13         2         3         0         0         0         1         5
# 14         3         1         0         0         1         1         6
#
#     Mean-Oct  Mean-Nov  Mean-Dec
# 0        236       398       509
# 1        185       275       411
# 2        167       243       266
# 3        135       300       467
# 4        145       191       228
# 5         32        76       172
# 6         76       145       193
# 7         29        77       201
# 8         66       108       229
# 9         34        95       143
# 10        29        29        37
# 11        16        35        27
# 12        21        29        47
# 13         5        10        30
# 14        12        40       146

# %%
temp_df[:15].sort_values(by='Mean-Jan', ascending=False).reset_index(drop=True)[['customs_description', 'Mean-Jan', 'Mean-Feb', 'Mean-Mar', 'Mean-Apr', 'Mean-May', 'Mean-Jun',
                                                                                 'Mean-Jul', 'Mean-Aug', 'Mean-Sep', 'Mean-Oct', 'Mean-Nov', 'Mean-Dec']]
# Out:
#                           customs_description  Mean-Jan  Mean-Feb  Mean-Mar  \
# 0                           January Sale 2021       275       169       171
# 1                           Ladies > Handbags       158        93       118
# 2             Ladies > Ladies Jackets & Coats       128        99       107
# 3                          Mens > Accessories       126        93        73
# 4       Mens > Leather Jackets > Biker Styles       115        81       100
# 5                           Ladies > Footwear        64        18        16
# 6                           Luggage > Holdall        59        28        37
# 7               Ladies > Accessories > Gloves        54        29        10
# 8                             Ladies > Purses        47        29        54
# 9     Mens > Man Bags & Briefcases > WashBags        20        17        13
# 10                     Mens > Mens Waistcoats        18        13        14
# 11                Mens > Mens Jackets & Coats        17         6         7
# 12  Mens > Man Bags & Briefcases > Briefcases        15        14        12
# 13           Sheepskin & Fur > Sheepskin Hats        12         5         2
# 14         Gift & Accessories > Ladies Gloves        10         5         3
#
#     Mean-Apr  Mean-May  Mean-Jun  Mean-Jul  Mean-Aug  Mean-Sep  Mean-Oct  \
# 0        159       166       111       136       158       181       236
# 1        130       170        93       127       137       168       185
# 2         96        80        34        47        56       120       167
# 3         59        57        67        66        77        82       135
# 4         83        77        41        49        76       115       145
# 5         10         8         4         6        12        20        32
# 6         41        46        47        49        67        76        76
# 7          7         3         1         1         5        10        29
# 8         33        36        30        27        44        52        66
# 9         14        13        19        18        27        26        34
# 10        14        22         7         9        15        11        29
# 11         5         2         2         2         3         9        16
# 12         9        11        10        13        20        14        21
# 13         3         0         0         0         1         5         5
# 14         1         0         0         1         1         6        12
#
#     Mean-Nov  Mean-Dec
# 0        398       509
# 1        275       411
# 2        243       266
# 3        300       467
# 4        191       228
# 5         76       172
# 6        145       193
# 7         77       201
# 8        108       229
# 9         95       143
# 10        29        37
# 11        35        27
# 12        29        47
# 13        10        30
# 14        40       146

# %%
temp_df[:15].sort_values(by='Mean-Jan', ascending=False).reset_index(drop=True)[['customs_description', 'Mean-Jan', 'Mean-Feb', 'Mean-Mar', 'Mean-Apr', 'Mean-May', 'Mean-Jun',
                                                                                 'Mean-Jul', 'Mean-Aug', 'Mean-Sep', 'Mean-Oct', 'Mean-Nov', 'Mean-Dec']]
# Out:
#                           customs_description  Mean-Jan  Mean-Feb  Mean-Mar  \
# 0                           January Sale 2021       275       169       171
# 1                           Ladies > Handbags       158        93       118
# 2             Ladies > Ladies Jackets & Coats       128        99       107
# 3                          Mens > Accessories       126        93        73
# 4       Mens > Leather Jackets > Biker Styles       115        81       100
# 5                           Ladies > Footwear        64        18        16
# 6                           Luggage > Holdall        59        28        37
# 7               Ladies > Accessories > Gloves        54        29        10
# 8                             Ladies > Purses        47        29        54
# 9     Mens > Man Bags & Briefcases > WashBags        20        17        13
# 10                     Mens > Mens Waistcoats        18        13        14
# 11                Mens > Mens Jackets & Coats        17         6         7
# 12  Mens > Man Bags & Briefcases > Briefcases        15        14        12
# 13           Sheepskin & Fur > Sheepskin Hats        12         5         2
# 14         Gift & Accessories > Ladies Gloves        10         5         3
#
#     Mean-Apr  Mean-May  Mean-Jun  Mean-Jul  Mean-Aug  Mean-Sep  Mean-Oct  \
# 0        159       166       111       136       158       181       236
# 1        130       170        93       127       137       168       185
# 2         96        80        34        47        56       120       167
# 3         59        57        67        66        77        82       135
# 4         83        77        41        49        76       115       145
# 5         10         8         4         6        12        20        32
# 6         41        46        47        49        67        76        76
# 7          7         3         1         1         5        10        29
# 8         33        36        30        27        44        52        66
# 9         14        13        19        18        27        26        34
# 10        14        22         7         9        15        11        29
# 11         5         2         2         2         3         9        16
# 12         9        11        10        13        20        14        21
# 13         3         0         0         0         1         5         5
# 14         1         0         0         1         1         6        12
#
#     Mean-Nov  Mean-Dec
# 0        398       509
# 1        275       411
# 2        243       266
# 3        300       467
# 4        191       228
# 5         76       172
# 6        145       193
# 7         77       201
# 8        108       229
# 9         95       143
# 10        29        37
# 11        35        27
# 12        29        47
# 13        10        30
# 14        40       146
