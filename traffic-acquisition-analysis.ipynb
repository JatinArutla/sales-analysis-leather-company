# %%
import pandas as pd

# %%
df = pd.read_csv('Channel-Wise-Traffic-Acquisition-2023.csv', skiprows=9)
df['Key events / Engaged sessions'] = df['Key events'] / df['Engaged sessions']
df.sort_values(by='Key events / Engaged sessions', ascending=False).reset_index(drop=True).round(3)
# Out:
#    Session primary channel group (Default Channel Group)   Users  Sessions  \
# 0                                          Unassigned     105506    138368
# 1                                            Referral      11698     19331
# 2                                              Direct     199129    249699
# 3                                               Email      10843     17788
# 4                                    Organic Shopping       1318      1523
# 5                                       Cross-network     418801    523261
# 6                                         Paid Search     100381    126028
# 7                                       Paid Shopping       3877      4461
# 8                                      Organic Search     174724    218475
# 9                                         Paid Social       1804      2184
# 10                                     Organic Social     208304    306606
# ...
