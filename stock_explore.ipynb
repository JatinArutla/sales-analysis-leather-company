# %%
import pandas as pd

df = pd.read_csv('stock_levels_12_feb.csv')

# %%
df.head()
# Out:
#    reference           ean  mpn  upc  product_id  parent_product_id  stock  \
# 0    4530800  5.061000e+12  NaN  NaN       20109               6777    603
# 1    4555300  5.061000e+12  NaN  NaN       20151               6795    595
# 2    2078000           NaN  NaN  NaN       14136               3923    510
# 3    2584100           NaN  NaN  NaN       10076               2645    446
# 4    4555500  5.061000e+12  NaN  NaN       20154               6798    393
#
#    total_sold  stock_cost_ex  stock_cost_inc  ...  \
# 0         NaN            NaN             NaN  ...
# 1         NaN            NaN             NaN  ...
# 2         NaN            NaN             NaN  ...
# 3         NaN            NaN             NaN  ...
# 4         NaN            NaN             NaN  ...
#
#                                                title  \
# 0  Ashwood Leather Crossbody Smart Phone Bag - Re...
# 1  Ashwood Zip Top Leather Cross Body Bag Black: ...
# ...

# %%
df[df['title'] == '00048268']
# Out:
#        reference  ean  mpn  upc  product_id  parent_product_id  stock  \
# 10098    4826810  NaN  NaN  NaN       22105               7531      0
# 10268    4826811  NaN  NaN  NaN       24263               7531      0
#
#        total_sold  stock_cost_ex  stock_cost_inc  ...     title  \
# 10098         NaN            NaN             NaN  ...  00048268
# 10268         NaN            NaN             NaN  ...  00048268
#
#                                        parent_title  parent_reference  \
# 10098  Ladies Leather Biker Jacket Beige: G-Celia22             48268
# 10268  Ladies Leather Biker Jacket Beige: G-Celia22             48268
#
#        attribute_summary      model  \
# 10098           Size: 26  G-CELIA22
# 10268           Size: 28  G-CELIA22
#
#                                              product_url  num_sold_period  \
# 10098  ladies-c3/leather-jackets-c9/ladies-leather-bi...                0
# 10268  ladies-c3/leather-jackets-c9/ladies-leather-bi...                0
#
# ...
