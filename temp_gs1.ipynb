# %%
import pandas as pd

# %%
df = pd.read_csv("last batch gs1.csv", skiprows=3, dtype=str)
df.head()
# Out:
#              Number  Status                       Product Name  \
# 0  ="5061049600007"  Active         TW-27-05-TB /  TAN-LT.BLUE
# 1  ="5061049600014"  Active            TW-27-06-NP / NAVY-PINK
# 2  ="5061049600021"  Active  TW-27-07-BR / BLACK-BLK/RED/GREEN
# 3  ="5061049600038"  Active    TW-27-08-TR / TAN-BLK/RED/GREEN
# 4  ="5061049600045"  Active          TW-27-09-BG / BROWN-GREEN
#
#                          Description Main Brand Sub Brand Product Link  MPN  \
# 0         TW-27-05-TB /  TAN-LT.BLUE    Ashwood       NaN          NaN  NaN
# 1            TW-27-06-NP / NAVY-PINK    Ashwood       NaN          NaN  NaN
# 2  TW-27-07-BR / BLACK-BLK/RED/GREEN    Ashwood       NaN          NaN  NaN
# 3    TW-27-08-TR / TAN-BLK/RED/GREEN    Ashwood       NaN          NaN  NaN
# 4          TW-27-09-BG / BROWN-GREEN    Ashwood       NaN          NaN  NaN
#
#    SKU                 Updated
# 0  NaN  ="23/02/2024 10:15:52"
# 1  NaN  ="23/02/2024 10:16:36"
# 2  NaN  ="23/02/2024 10:17:19"
# ...
