# %%
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)

# %%
df = pd.read_csv("Search Analysis/Queries.csv")

# %%
df['CTR'] = df['CTR'].astype(str)
df['CTR'] = df['CTR'].str.replace('%', '')
df['CTR'] = df['CTR'].astype(float)
df[(df['Impressions'] > 100) & (df['Impressions'] < 500)].sort_values(by='CTR', ascending=False).reset_index(drop=True)[:100]
# Out:
#                                                            Top queries  \
# 0                                                 leathercompany.co.uk
# 1                                         the leather company solihull
# 2                                                      mp leather bags
# 3                                         trapper leather jacket price
# 4                                                  www.leather company
# 5                                                      trapper leather
# 6                                        trapper original leather wear
# 7                                             fenland sheepskin gloves
# 8                                                      marta ponti bag
# 9                                                      fenland leather
# 10                                                      ashwood jacket
# 11                                                      fenland gloves
# ...
