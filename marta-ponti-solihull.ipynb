# %%
import pandas as pd

# %%
dfb = pd.read_csv('Fashione-EAN-PLU.csv', dtype=str)
dfa = pd.read_csv("Fashione SKUs after deleting MP.csv", dtype=str)

# %%
before = dfb['PLU'].unique()
after = dfa['PLU'].unique()

# %%
deleted = list(set(before) - set(after))

# %%
dfb_temp = dfb[dfb['PLU'].isin(deleted)]
dfb_temp
# Out:
#              Brand       Style Colour Size        Description         PLU  \
# 39496  MARTA PONTI     3120685  BLACK  NaN          briefcase  0002939000
# 39499  MARTA PONTI     3120815  BLACK  NaN          briefcase  0002939200
# 39501  MARTA PONTI     8105817  BLACK  NaN            handbag  0002939400
# 39502  MARTA PONTI     8105817   BLUE  NaN            handbag  0002939500
# 39503  MARTA PONTI     8105817    RED  NaN            handbag  0002939600
# ...            ...         ...    ...  ...                ...         ...
# 39656  MARTA PONTI  MP B225015  BLACK  NaN             wallet  0003934300
# 39657  MARTA PONTI  MP B225023  BLACK  NaN             wallet  0003933800
# 39658  MARTA PONTI  MP B225024  BLACK  NaN             wallet  0003934200
# 39659  MARTA PONTI  MP B225025  BLACK  NaN             wallet  0003933000
# 39660  MARTA PONTI  MP B225026  BLACK  NaN  key holder wallet  0003933700
#
#        EAN  SKU Comm Code Unnamed: 9
# 39496  NaN  NaN       NaN        NaN
# ...
