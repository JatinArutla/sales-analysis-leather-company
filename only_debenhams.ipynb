# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df = pd.read_csv('jatin.csv', sep=';', low_memory=False)
df[df['Status'] == 'Refunded'][['Order number', 'Date created', 'Shipping date']].iloc[:5]
# Out:
#      Order number           Date created          Shipping date
# 0  DUX008910341-A  25/01/2023 - 16:22:22  26/01/2023 - 11:12:18
# 1  DUX008919334-A  26/01/2023 - 11:27:03                    NaN
# 2  DUX008919578-A  26/01/2023 - 11:53:52                    NaN
# 3  DUX008919578-A  26/01/2023 - 11:53:52                    NaN
# 4  DUX008919770-A  26/01/2023 - 12:15:46  26/01/2023 - 12:25:18

# %%
df[df['Order number'] == 'DUX008910341-A']
# Out:
#             Date created    Order number  Quantity  \
# 0  25/01/2023 - 16:22:22  DUX008910341-A         1
#
#                                              Details    Status  Amount  \
# 0  'Pretty' Leather Shoulder Bag (Product SKU : M...  Refunded   59.99
#
#   Currency      Shipping method Customer debit date   Payment workflow  \
# 0      GBP  UK Express Delivery          25/01/2023  Pay on Acceptance
#
#    Shop SKU Reason Offer SKU            Brand Offer state    Order line no.  \
# 0   4473500    NaN    S27358  Ashwood Leather         New  DUX008910341-A-1
#
#    Unit price  Shipping price  Shipping total amount  \
# 0       59.99             0.0                    0.0
#
#    Total order amount incl. VAT (including shipping charges)  \
# 0                                              59.99
#
#    Commission (excluding taxes)  Commission value (including taxes)  \
# 0                          12.0                                14.4
#
# ...
